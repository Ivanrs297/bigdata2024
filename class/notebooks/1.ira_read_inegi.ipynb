# %% [markdown]
# # EDA : Exploratory Data Analysis

# %%
# !pip install pandas
# !pip install matplotlib

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/conjunto_de_datos_cb_enco_2024_06.CSV")
df
# Out:
#       cd  per  n_ent     fol  ent    con  v_sel  n_hog  h_mud  n_ren  ...  p7  \
# 0     14  624      6  12A221    1  40082      4      1      0      1  ...   3
# 1     14  624      6  12A221    1  40082      1      1      0      2  ...   2
# 2     14  624      6  12A221    1  40082      2      1      0      5  ...   3
# 3     14  624      6  12A221    1  40082      3      1      0      2  ...   2
# 4     14  624      1  11B226    1  40168      4      1      0      2  ...   1
# ...   ..  ...    ...     ...  ...    ...    ...    ...    ...    ...  ...  ..
# 2005  32  624      7  12B218   32  40300      4      1      0      1  ...   3
# 2006  32  624      4  12B223   32  40386      1      1      0      2  ...   2
# 2007  32  624      4  12B223   32  40386      2      1      0      1  ...   3
# 2008  32  624      4  12B223   32  40386      3      1      0      2  ...   3
# 2009  32  624      4  12B223   32  40386      4      1      0      1  ...   2
#
# ...

# %%
df["cd"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>
